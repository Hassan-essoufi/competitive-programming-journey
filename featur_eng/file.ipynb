# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.array([
    [1, 200],
    [2, 300],
    [3, 400],
    [4, 500]
], dtype=float)

print("Original Data:\n", X)
# Out:
# Original Data:
#  [[  1. 200.]
#  [  2. 300.]
#  [  3. 400.]
#  [  4. 500.]]

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

S_scaler = StandardScaler()
x_new = S_scaler.fit_transform(X)
print("standardized data:\n", x_new)
# Out:
# standardized data:
#  [[-1.34164079 -1.34164079]
#  [-0.4472136  -0.4472136 ]
#  [ 0.4472136   0.4472136 ]
#  [ 1.34164079  1.34164079]]

# %%
# Normalization
from sklearn.preprocessing import MinMaxScaler
M_scaler = MinMaxScaler((0,1))
x_scaled = M_scaler.fit_transform(X)
print("scaled data :\n", x_scaled)
# Out:
# scaled data :
#  [[0.         0.        ]
#  [0.33333333 0.33333333]
#  [0.66666667 0.66666667]
#  [1.         1.        ]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Linear Regression

from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

data = load_iris()
x = data.data
y = data.target
x_train, x_test , y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# Metrics
R_score = r2_score(y_test, y_pred)
print("model's coeficients:",model.coef_)
print("model's bias:", model.intercept_)
print("loss function : mean", mean_squared_error(y_test, y_pred))
print("loss function : absolute", mean_absolute_error(y_test, y_pred))
print("model performance", R_score)
# Out:
# model's coeficients: [-0.10753506 -0.05844926  0.2647557   0.52929416]
# model's bias: 0.18080804062268085
# loss function : mean 0.03866591237825791
# loss function : absolute 0.15332265627129668
# model performance 0.9442318571467434

# %%
# Polynomial regression
from sklearn.preprocessing import PolynomialFeatures

lr =LinearRegression()
poly = PolynomialFeatures(degree=3,include_bias=False)
x_train_p = poly.fit_transform(x_train)
print(x_train_p[:3])
x_test_p = poly.fit_transform(x_test)
lr.fit(x_train_p, y_train)
predictions = lr.predict(x_test_p)

# Metrics
R_score = r2_score(y_test, y_pred)
print("model's coeficients:",model.coef_)
print("model's bias:", model.intercept_)
print("loss function : mean", mean_squared_error(y_test, predictions))
print("loss function : absolute", mean_absolute_error(y_test, predictions))
print("model performance", R_score)
# Out:
# [[  5.5     2.4     3.7     1.     30.25   13.2    20.35    5.5     5.76
#     8.88    2.4    13.69    3.7     1.    166.375  72.6   111.925  30.25
#    31.68   48.84   13.2    75.295  20.35    5.5    13.824  21.312   5.76
#    32.856   8.88    2.4    50.653  13.69    3.7     1.   ]
#  [  6.3     2.8     5.1     1.5    39.69   17.64   32.13    9.45    7.84
#    14.28    4.2    26.01    7.65    2.25  250.047 111.132 202.419  59.535
#    49.392  89.964  26.46  163.863  48.195  14.175  21.952  39.984  11.76
#    72.828  21.42    6.3   132.651  39.015  11.475   3.375]
#  [  6.4     3.1     5.5     1.8    40.96   19.84   35.2    11.52    9.61
#    17.05    5.58   30.25    9.9     3.24  262.144 126.976 225.28   73.728
#    61.504 109.12   35.712 193.6    63.36   20.736  29.791  52.855  17.298
#    93.775  30.69   10.044 166.375  54.45   17.82    5.832]]
# model's coeficients: [-0.10753506 -0.05844926  0.2647557   0.52929416]
# model's bias: 0.18080804062268085
# ...

# %%
# L1 Lasso regression
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.8)
lasso.fit(x_train, y_train)
y_pred = lasso.predict(x_test)

print(r2_score(y_test, y_pred))
# Out:
# 0.5536104635044501

# %%
# L2 Ridge regression
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.9)
ridge.fit(x_train, y_train)
y_pred = ridge.predict(x_test)

print(r2_score(y_test, y_pred))
# Out:
# 0.9421213808990276

# %%
# ElasticNet regression
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=0.5, l1_ratio=0.2)
elasticnet.fit(x_train, y_train)
y_pred = elasticnet.predict(x_test)

print(r2_score(y_test, y_pred))
# Out:
# 0.8873061069146636

# %%
# Cross validations Techniques
from sklearn.datasets import load_iris

data = load_iris()
x = data.data
y = data.target

# KFold
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
cv_score = cross_val_score(lr, x, y, cv=kfold)
print(cv_score.mean())

# Stratified KFold
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_score = cross_val_score(lr, x, y, cv=kfold)
print(cv_score.mean())

# loocv
from sklearn.model_selection import LeaveOneOut

loo = LeaveOneOut()
model = LinearRegression()

mse_list = []

for train_index, test_index in loo.split(x):
    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    
    mse = mean_squared_error(y_test, y_pred)
    mse_list.append(mse)

# Average LOOCV error
loocv_error = np.mean(mse_list)
print("LOOCV MSE:", loocv_error)
# Out:
# 0.9239837362538136
# 0.9237613876852147
# LOOCV MSE: 0.049541853251845805
